# %% [markdown]
# # Tweets Collecting Script

# %% [markdown]
# ## Acquiring Dataset (ElSherief et al., 2018) from Twitter using Twitter API and Twitter ID

# %%
import os
import tweepy as tw
import pandas as pd

consumer_key = None #Input your own Twitter developer access here
consumer_secret = None
access_token = None
access_token_secret = None

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#Defining tweet ID
tweet_id_list = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Capstone Project/Data/English/ethn_whitepower.csv')

tweet_id = tweet_id_list.iloc[0,0]

tweet_id

# %%
#Acquiring individual tweets
tweet = api.get_status(tweet_id)
print(tweet.text)
# Out:
# @cristinalaila1 @Sttbs73
# YES He did. Back in the glory days of the KKK and ALL the closet democrat elected in DC. #EVIL,
# #WhitePower

# %%
# This method creates the training set
def createTrainingSet(corpusFile, targetResultFile):
    import csv
    import time

    counter = 0
    corpus = []

    with open(corpusFile, 'r') as csvfile:
        lineReader = csv.reader(csvfile, delimiter=',', quotechar="\"")
        for row in lineReader:
            corpus.append({"tweet_id": row[0]})

    sleepTime = 2
    trainingDataSet = []

    for tweet in corpus:
        try:
            tweetFetched = api.get_status(tweet["tweet_id"])
            print("Tweet fetched" + tweetFetched.text)
            tweet["text"] = tweetFetched.text
            trainingDataSet.append(tweet)
            time.sleep(sleepTime)

        except:
            print("Inside the exception - no:2")
            continue

    with open(targetResultFile, 'a') as csvfile:
        linewriter = csv.writer(csvfile, delimiter=',', quotechar="\"")
        for tweet in trainingDataSet:
            try:
                linewriter.writerow([tweet["tweet_id"], tweet["text"]])
            except Exception as e:
                print(e)
    return trainingDataSet

# %%
corpusFile = '/content/drive/MyDrive/Colab Notebooks/Capstone Project/Data/English/Tweet IDs/sexorient_faggot.csv'

targetResultFile = '/content/drive/MyDrive/Colab Notebooks/Capstone Project/Data/English/data.csv'

resultFile = createTrainingSet(corpusFile, targetResultFile)
# Out:
# Inside the exception - no:2
# Inside the exception - no:2
# Inside the exception - no:2
# Inside the exception - no:2
# Inside the exception - no:2
# Tweet fetched@GershKuntzman You actually got PTSD from a shooting range? Ah yes a typical hook faggot like yourself would insult PTSD survivors.
# Tweet fetched@Johnvalle20 goes to show how you were raised by your moronic parents, having a stupid son/faggot like ... https://t.co/lUc7RNmejU
# Inside the exception - no:2
# Inside the exception - no:2
# Inside the exception - no:2
# Tweet fetched@andrew_szcz I'll be happy when you stop tweeting like a little faggot
# Inside the exception - no:2
# Inside the exception - no:2
# Tweet fetched@ballardtom123 @JohnInSportz @clevelanddotcom dude ur a fucking duchebag get blogged faggot
# Inside the exception - no:2
# Inside the exception - no:2
# Inside the exception - no:2
# Tweet fetched@Dropz97 play on your own ladder fucking faggot
# Inside the exception - no:2
# Inside the exception - no:2
# ...
